# %% [markdown]
# #### Introduction

# %% [markdown]
# - 100 volunteers provide a semen sample analyzed according to the WHO 2010 criteria.
# - Sperm concentration are related to socio-demographic data, environmental factors, health status, and life habits
# - Analysis goining on on the basis of data gven and finding the factors that badly affect he reproduction process

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import warnings
warnings.filterwarnings("ignore")

# %%
df=pd.read_csv(r"C:\edubridge datas\fertility.CSV")

# %%
df
# Out:
#     Season  Age Childish diseases Accident or serious trauma  \
# 0   spring   30                no                        yes
# 1   spring   35               yes                         no
# 2   spring   27               yes                         no
# 3   spring   32                no                        yes
# 4   spring   30               yes                        yes
# ..     ...  ...               ...                        ...
# 95  winter   30               yes                         no
# 96  winter   29               yes                         no
# 97  winter   30               yes                        yes
# 98  winter   30               yes                         no
# 99  winter   30                no                        yes
#
#    Surgical intervention High fevers in the last year  \
# 0                    yes       more than 3 months ago
# 1                    yes       more than 3 months ago
# 2                     no       more than 3 months ago
# ...

# %% [markdown]
# - Season in which the analysis was performed.
# - 1) winter, 2) spring, 3) Summer, 4) fall.
# - Age at the time of analysis. 18-36 (0, 1)
# - Childish diseases (ie , chicken pox, measles, mumps, polio) 1) yes, 2) no
# - Accident or serious trauma 1) yes, 2) no. (0, 1)
# - Surgical intervention 1) yes, 2) no. (0, 1)
# - High fevers in the last year 1) less than three months ago, 2) more than three months ago, 3) no.
# - Frequency of alcohol consumption 1) several times a day, 2) every day, 3) several times a week, 4) once a week, 5) hardly ever or never
# - Smoking habit 1) never, 2) occasional 3) daily
# - Number of hours spent sitting per day ene-16
# - Output: Diagnosis normal (N), altered (O)

# %% [markdown]
# #### reading  frst 5 rows

# %%
df.head()
# Out:
#    Season  Age Childish diseases Accident or serious trauma  \
# 0  spring   30                no                        yes
# 1  spring   35               yes                         no
# 2  spring   27               yes                         no
# 3  spring   32                no                        yes
# 4  spring   30               yes                        yes
#
#   Surgical intervention High fevers in the last year  \
# 0                   yes       more than 3 months ago
# 1                   yes       more than 3 months ago
# 2                    no       more than 3 months ago
# 3                   yes       more than 3 months ago
# 4                    no       more than 3 months ago
#
#   Frequency of alcohol consumption Smoking habit  \
# 0                      once a week    occasional
# 1                      once a week         daily
# 2             hardly ever or never         never
# 3             hardly ever or never         never
# ...

# %% [markdown]
# #### last 5 rows

# %%
df.tail()
# Out:
#     Season  Age Childish diseases Accident or serious trauma  \
# 95  winter   30               yes                         no
# 96  winter   29               yes                         no
# 97  winter   30               yes                        yes
# 98  winter   30               yes                         no
# 99  winter   30                no                        yes
#
#    Surgical intervention High fevers in the last year  \
# 95                    no       more than 3 months ago
# 96                    no       more than 3 months ago
# 97                   yes       more than 3 months ago
# 98                   yes       more than 3 months ago
# 99                   yes       more than 3 months ago
#
#    Frequency of alcohol consumption Smoking habit  \
# 95             hardly ever or never         never
# 96                      once a week    occasional
# 97             hardly ever or never         never
# 98             hardly ever or never    occasional
# ...

# %% [markdown]
# #### information about dataset

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 100 entries, 0 to 99
# Data columns (total 10 columns):
#  #   Column                                 Non-Null Count  Dtype
# ---  ------                                 --------------  -----
#  0   Season                                 100 non-null    object
#  1   Age                                    100 non-null    int64
#  2   Childish diseases                      100 non-null    object
#  3   Accident or serious trauma             100 non-null    object
#  4   Surgical intervention                  100 non-null    object
#  5   High fevers in the last year           100 non-null    object
#  6   Frequency of alcohol consumption       100 non-null    object
#  7   Smoking habit                          100 non-null    object
#  8   Number of hours spent sitting per day  100 non-null    int64
#  9   Diagnosis                              100 non-null    object
# dtypes: int64(2), object(8)
# memory usage: 7.9+ KB

# %% [markdown]
# #### statistical analysis of data

# %%
df.describe()
# Out:
#               Age  Number of hours spent sitting per day
# count  100.000000                             100.000000
# mean    30.110000                              10.800000
# std      2.246861                              33.616975
# min     27.000000                               1.000000
# 25%     28.000000                               5.000000
# 50%     30.000000                               7.000000
# 75%     32.000000                               9.000000
# max     36.000000                             342.000000

# %%
df.describe(include="all")
# Out:
#         Season         Age Childish diseases Accident or serious trauma  \
# count      100  100.000000               100                        100
# unique       4         NaN                 2                          2
# top     spring         NaN               yes                         no
# freq        37         NaN                87                         56
# mean       NaN   30.110000               NaN                        NaN
# std        NaN    2.246861               NaN                        NaN
# min        NaN   27.000000               NaN                        NaN
# 25%        NaN   28.000000               NaN                        NaN
# 50%        NaN   30.000000               NaN                        NaN
# 75%        NaN   32.000000               NaN                        NaN
# max        NaN   36.000000               NaN                        NaN
#
#        Surgical intervention High fevers in the last year  \
# ...

# %% [markdown]
# #### finding shape that how many column and howmany rows

# %%
df.shape
# Out:
# (100, 10)

# %% [markdown]
# #### checking null values

# %%
df.isnull()
# Out:
#     Season    Age  Childish diseases  Accident or serious trauma  \
# 0    False  False              False                       False
# 1    False  False              False                       False
# 2    False  False              False                       False
# 3    False  False              False                       False
# 4    False  False              False                       False
# ..     ...    ...                ...                         ...
# 95   False  False              False                       False
# 96   False  False              False                       False
# 97   False  False              False                       False
# 98   False  False              False                       False
# 99   False  False              False                       False
#
#     Surgical intervention  High fevers in the last year  \
# 0                   False                         False
# 1                   False                         False
# ...

# %%
df.isnull().sum()
# Out:
# Season                                   0
# Age                                      0
# Childish diseases                        0
# Accident or serious trauma               0
# Surgical intervention                    0
# High fevers in the last year             0
# Frequency of alcohol consumption         0
# Smoking habit                            0
# Number of hours spent sitting per day    0
# Diagnosis                                0
# dtype: int64

# %% [markdown]
# ##### checking duplicate values

# %%
df.duplicated().sum
# Out:
# <bound method NDFrame._add_numeric_operations.<locals>.sum of 0     False
# 1     False
# 2     False
# 3     False
# 4     False
#       ...
# 95    False
# 96    False
# 97    False
# 98    False
# 99    False
# Length: 100, dtype: bool>

# %% [markdown]
# ##### finding datatypes

# %%
df.dtypes
# Out:
# Season                                   object
# Age                                       int64
# Childish diseases                        object
# Accident or serious trauma               object
# Surgical intervention                    object
# High fevers in the last year             object
# Frequency of alcohol consumption         object
# Smoking habit                            object
# Number of hours spent sitting per day     int64
# Diagnosis                                object
# dtype: object

# %% [markdown]
# ##### statistical analiss of single column

# %%
df['Diagnosis'].count()
# Out:
# 100

# %%
df['Number of hours spent sitting per day'].max()
# Out:
# 342

# %%
df['Number of hours spent sitting per day'].min()
# Out:
# 1

# %%
df['Number of hours spent sitting per day'].std()
# Out:
# 33.61697502900892

# %%
df['Number of hours spent sitting per day'].var()
# Out:
# 1130.1010101010093

# %%
df['Number of hours spent sitting per day'].var()
# Out:
# 1130.1010101010093

# %%
df['Smoking habit'].value_counts()
# Out:
# never         56
# occasional    23
# daily         21
# Name: Smoking habit, dtype: int64

# %%
df['Frequency of alcohol consumption'].value_counts()
# Out:
# hardly ever or never    40
# once a week             39
# several times a week    19
# several times a day      1
# every day                1
# Name: Frequency of alcohol consumption, dtype: int64

# %%
df['Frequency of alcohol consumption'].unique()
# Out:
# array(['once a week', 'hardly ever or never', 'several times a week',
#        'several times a day', 'every day'], dtype=object)

# %%
df['Smoking habit'].unique()
# Out:
# array(['occasional', 'daily', 'never'], dtype=object)

# %% [markdown]
# #### changing the column name for easy analysis

# %%
df.rename(columns={'Accident or serious trauma':"accidents"},inplace=True)
df.rename(columns={'Surgical intervention':"surgeries"},inplace=True)
df.rename(columns={'High fevers in the last year':"feverlastyear"},inplace=True)
df.rename(columns={'Frequency of alcohol consumption':"alcoholconsumption"},inplace=True)
df.rename(columns={'Smoking habit':"Smokinghabit"},inplace=True)
df.rename(columns={'Number of hours spent sitting per day':" sittinghourperday"},inplace=True)
df.rename(columns={'Childish diseases':"Childishdiseases"},inplace=True)

# %%
df
# Out:
#     Season  Age Childishdiseases accidents surgeries           feverlastyear  \
# 0   spring   30               no       yes       yes  more than 3 months ago
# 1   spring   35              yes        no       yes  more than 3 months ago
# 2   spring   27              yes        no        no  more than 3 months ago
# 3   spring   32               no       yes       yes  more than 3 months ago
# 4   spring   30              yes       yes        no  more than 3 months ago
# ..     ...  ...              ...       ...       ...                     ...
# 95  winter   30              yes        no        no  more than 3 months ago
# 96  winter   29              yes        no        no  more than 3 months ago
# 97  winter   30              yes       yes       yes  more than 3 months ago
# 98  winter   30              yes        no       yes  more than 3 months ago
# 99  winter   30               no       yes       yes  more than 3 months ago
#
# ...

# %% [markdown]
# #### converting all values to the numerical format

# %%
df.Season=df.Season.replace({'spring':0,"winter":1,"summer":2,"fall":3})
df.Childishdiseases=df.Childishdiseases.replace({'no':0,"yes":1})
df.surgeries=df.surgeries.replace({"yes":1,"no":0})
df.feverlastyear=df.feverlastyear.replace({"less than 3 months ago":0,"more than 3 months ago":1,"no":2})
df.alcoholconsumption=df.alcoholconsumption.replace({"several times a day":0,"every day":1,"several times a week":2,"once a week":3,"hardly ever or never":4})
df.Smokinghabit=df.Smokinghabit.replace({"never":0,"occasional":1,"daily":2})
df.accidents=df.accidents.replace({"no":0,"yes":1})

# %%
df
# Out:
#     Season  Age  Childishdiseases  accidents  surgeries  feverlastyear  \
# 0        0   30                 0          1          1              1
# 1        0   35                 1          0          1              1
# 2        0   27                 1          0          0              1
# 3        0   32                 0          1          1              1
# 4        0   30                 1          1          0              1
# ..     ...  ...               ...        ...        ...            ...
# 95       1   30                 1          0          0              1
# 96       1   29                 1          0          0              1
# 97       1   30                 1          1          1              1
# 98       1   30                 1          0          1              1
# 99       1   30                 0          1          1              1
#
#     alcoholconsumption  Smokinghabit   sittinghourperday Diagnosis
# ...

# %% [markdown]
# #### box plot from this we can analyse sittinghours per day have more outlayer than other features

# %%
df.plot(kind='box',figsize=(8,5),vert=False)
plt.show()

# %%
sns.pairplot(df,hue='Diagnosis')
plt.show()

# %% [markdown]
# ##### correlation

# %%
df.corr()
# Out:
#                       Season       Age  Childishdiseases  accidents  \
# Season              1.000000 -0.029276         -0.148039  -0.237621
# Age                -0.029276  1.000000          0.098824   0.235735
# Childishdiseases   -0.148039  0.098824          1.000000   0.162936
# accidents          -0.237621  0.235735          0.162936   1.000000
# surgeries           0.028615 -0.254032          0.140972  -0.103166
# feverlastyear      -0.048542  0.154124          0.075645  -0.082278
# alcoholconsumption -0.015727 -0.240266          0.038538  -0.242722
# Smokinghabit       -0.048166  0.076990          0.090535   0.110157
#  sittinghourperday -0.113532 -0.046645          0.025247  -0.087452
#
#                     surgeries  feverlastyear  alcoholconsumption  \
# Season               0.028615      -0.048542           -0.015727
# Age                 -0.254032       0.154124           -0.240266
# Childishdiseases     0.140972       0.075645            0.038538
# ...

# %% [markdown]
# #### A positive correlation exists when two variables operate in unison so that when one variable rises or falls, the other does the same.
# #### A negative correlation is when two variables move opposite one another so that when one variable rises, the other falls.

# %% [markdown]
# #### covariance

# %%
df.cov()
# Out:
#                       Season       Age  Childishdiseases  accidents  \
# Season              1.581717 -0.082727         -0.062929  -0.149091
# Age                -0.082727  5.048384          0.075051   0.264242
# Childishdiseases   -0.062929  0.075051          0.114242   0.027475
# accidents          -0.149091  0.264242          0.027475   0.248889
# surgeries           0.018081 -0.286768          0.023939  -0.025859
# feverlastyear      -0.035455  0.201111          0.014848  -0.023838
# alcoholconsumption -0.016566 -0.452121          0.010909  -0.101414
# Smokinghabit       -0.048990  0.139899          0.024747   0.044444
#  sittinghourperday -4.800000 -3.523232          0.286869  -1.466667
#
#                     surgeries  feverlastyear  alcoholconsumption  \
# Season               0.018081      -0.035455           -0.016566
# Age                 -0.286768       0.201111           -0.452121
# Childishdiseases     0.023939       0.014848            0.010909
# ...

# %% [markdown]
# #### Covariance gives you a positive number if the variables are positively related.
# #### we ’ll get a negative number if they are negatively related. A high covariance basically indicates there is a strong relationship between the variables. A low value means there is a weak relationship.

# %%
sns.distplot(df.Childishdiseases)
plt.title("Distribution plot of diasese")
plt.show()

# %% [markdown]
# - most of the people have childish diseases the dencity is more than 8

# %%
plt.figure(figsize=(15,4))
sns.countplot(x=df["alcoholconsumption"])
plt.xticks(rotation=90)
plt.show()

# %% [markdown]
# - most peole are not having alcohol
# - people below 5 percentage have more than one time in a day

# %%
plt.figure(figsize=(15,4))
sns.countplot(x=df["accidents"])
plt.xticks(rotation=90)
plt.show()

# %% [markdown]
# - 40 and above people faced accident in the childwood time
# - rest of them are not

# %%
plt.figure(figsize=(15,4))
sns.countplot(x=df["surgeries"])
plt.xticks(rotation=90)
plt.show()

# %% [markdown]
# - 50 percentage peple had surgeries and remaining 50 had not done any surgeries

# %%
plt.bar(df['Diagnosis'],df['accidents'],color='black')
plt.title('diagonosis and accident',fontsize=15,color='red')
plt.xlabel('diagonosis',fontsize=15)
plt.ylabel('accident',fontsize=15)
plt.show()

# %% [markdown]
# - people faced any accident and those who not faced any accident in childwood have ame persentage in diagonosis

# %%
plt.bar(df['Diagnosis'],df['Smokinghabit'],color='black')
plt.title('diagonosis and smoking',fontsize=15,color='red')
plt.xlabel('diagonosis',fontsize=15)
plt.ylabel('smoking',fontsize=15)
plt.show()

# %% [markdown]
# - 50 percentage people affected with fertilisation problem beause of smoking

# %%
plt.title('feverlastyear',fontsize=20)
df['feverlastyear'].value_counts().plot.pie(autopct='%1.1f%%',shadow=True)
plt.show()

# %% [markdown]
# - 63 percentage people having fever morethan 3 month
# - only 9 percentage people dont geting fever

# %%
plt.title('accidents',fontsize=20)
df['accidents'].value_counts().plot.pie(autopct='%1.1f%%',shadow=True)
plt.show()

# %% [markdown]
# ### conclusion

# %% [markdown]
# - Overexposure to certain environmental factors, such as pesticides and other chemicals, and radiation.
# - Cigarette smoking, alcohol, marijuana, anabolic steroids, and taking medications to treat bacterial infections, high blood pressure and depression also can affect fertility.
# - sitting time per day also aftect the reproduction,from the above analysis can understand those who are ivesting more hour in there diagonosis there will be some alteration
# - daily alchoholic  peple also affect with fertilization prblm

# %% [markdown]
# ### machine learning part

# %%
x=df.drop("Diagnosis",axis=1)
x
# Out:
#     Season  Age  Childishdiseases  accidents  surgeries  feverlastyear  \
# 0        0   30                 0          1          1              1
# 1        0   35                 1          0          1              1
# 2        0   27                 1          0          0              1
# 3        0   32                 0          1          1              1
# 4        0   30                 1          1          0              1
# ..     ...  ...               ...        ...        ...            ...
# 95       1   30                 1          0          0              1
# 96       1   29                 1          0          0              1
# 97       1   30                 1          1          1              1
# 98       1   30                 1          0          1              1
# 99       1   30                 0          1          1              1
#
#     alcoholconsumption  Smokinghabit   sittinghourperday
# 0                    3             1                  16
# ...

# %%
y=df.Diagnosis
y
# Out:
# 0      Normal
# 1     Altered
# 2      Normal
# 3      Normal
# 4     Altered
#        ...
# 95     Normal
# 96     Normal
# 97     Normal
# 98     Normal
# 99     Normal
# Name: Diagnosis, Length: 100, dtype: object

# %%
from sklearn.model_selection  import train_test_split

# %%
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.3)

# %%
print(x_train.shape)
print(x_test.shape)
print(y_test.shape)
print(y_train.shape)
# Out:
# (70, 9)
# (30, 9)
# (30,)
# (70,)

# %%
from sklearn.linear_model import LogisticRegression

# %%
reg=LogisticRegression()

# %%
reg.fit(x_train,y_train)
# Out:
# LogisticRegression()

# %%
predict=reg.predict(x_test)

# %%
predict
# Out:
# array(['Normal', 'Normal', 'Normal', 'Normal', 'Normal', 'Normal',
#        'Normal', 'Normal', 'Normal', 'Normal', 'Normal', 'Normal',
#        'Normal', 'Normal', 'Normal', 'Normal', 'Normal', 'Normal',
#        'Normal', 'Normal', 'Normal', 'Normal', 'Normal', 'Normal',
#        'Normal', 'Normal', 'Normal', 'Normal', 'Normal', 'Normal'],
#       dtype=object)

# %%
d=pd.DataFrame({"actual":y_test,"predicted":predict})
d
# Out:
#      actual predicted
# 53   Normal    Normal
# 99   Normal    Normal
# 3    Normal    Normal
# 25   Normal    Normal
# 84  Altered    Normal
# 30   Normal    Normal
# 32   Normal    Normal
# 54   Normal    Normal
# 2    Normal    Normal
# 5    Normal    Normal
# 66   Normal    Normal
# 33   Normal    Normal
# 10   Normal    Normal
# 80   Normal    Normal
# 92   Normal    Normal
# 72   Normal    Normal
# 69   Normal    Normal
# 16   Normal    Normal
# 41   Normal    Normal
# 73   Normal    Normal
# 87   Normal    Normal
# 64   Normal    Normal
# 18   Normal    Normal
# 39   Normal    Normal
# 28   Normal    Normal
# 44   Normal    Normal
# 19  Altered    Normal
# 12   Normal    Normal
# 29  Altered    Normal
# 74   Normal    Normal

# %%
reg.predict([[0,30,0,1,1,1,3,1,16]])
# Out:
# array(['Normal'], dtype=object)

# %%
reg.score(x_test,y_test)*100
# Out:
# 90.0
